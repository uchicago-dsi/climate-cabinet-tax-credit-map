# %% [markdown]
# # Justice40
#
# Exploratory data analysis of raw Justice40 census tracts.

# %% [markdown]
# #### Summary
#
# The dataset contains all U.S. census tracts for 2010 (74,134 records), of which 27,248 are classified as a Justice40 community. There are 124 total columns, but the relevant ones appear to be the tract FIPS Code (`GEOID10`) and the disadvantaged indiator (`SN_C`). (For more information, please consult the data dictionary, "columns.csv", saved with the Shapefile.) The dataset uses a coordinate reference system (CRS) of EPSG:4326.

# %% [markdown]
# #### Exploration

# %%
import geopandas as gpd

# %%
data: gpd.GeoDataFrame = gpd.read_file(
    filename=f"../data/raw/bonus/justice40/usa.zip",
    dtype=str)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/launagreer/clinic/climate-cabinet-tax-credit-map/scratch/notebooks/justice40.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/launagreer/clinic/climate-cabinet-tax-credit-map/scratch/notebooks/justice40.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> data: gpd.GeoDataFrame = gpd.read_file(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/launagreer/clinic/climate-cabinet-tax-credit-map/scratch/notebooks/justice40.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     filename=f"../data/raw/bonus/justice40/usa.zip",
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/launagreer/clinic/climate-cabinet-tax-credit-map/scratch/notebooks/justice40.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     na_values=None,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/launagreer/clinic/climate-cabinet-tax-credit-map/scratch/notebooks/justice40.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     dtype=str)
#
# File ~/clinic/climate-cabinet-tax-credit-map/env/lib/python3.8/site-packages/geopandas/io/file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     278     else:
#     279         path_or_bytes = filename
# --> 281     return _read_file_fiona(
#     282         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     283     )
#     285 else:
#     286     raise ValueError(f"unknown engine '{engine}'")
#
# File ~/clinic/climate-cabinet-tax-credit-map/env/lib/python3.8/site-packages/geopandas/io/file.py:379, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     375     df = pd.DataFrame(
#     376         [record["properties"] for record in f_filt], columns=columns
#     377     )
#     378 else:
# --> 379     df = GeoDataFrame.from_features(
#     380         f_filt, crs=crs, columns=columns + ["geometry"]
#     381     )
#     382 for k in datetime_fields:
#     383     as_dt = pd.to_datetime(df[k], errors="ignore")
#
# File ~/clinic/climate-cabinet-tax-credit-map/env/lib/python3.8/site-packages/geopandas/geodataframe.py:640, in GeoDataFrame.from_features(cls, features, crs, columns)
#     637 if hasattr(feature, "__geo_interface__"):
#     638     feature = feature.__geo_interface__
#     639 row = {
# --> 640     "geometry": shape(feature["geometry"]) if feature["geometry"] else None
#     641 }
#     642 # load properties
#     643 properties = feature["properties"]
#
# File ~/clinic/climate-cabinet-tax-credit-map/env/lib/python3.8/site-packages/shapely/geometry/geo.py:102, in shape(context)
#     100     return LinearRing(ob["coordinates"])
#     101 elif geom_type == "polygon":
# --> 102     return Polygon(ob["coordinates"][0], ob["coordinates"][1:])
#     103 elif geom_type == "multipoint":
#     104     return MultiPoint(ob["coordinates"])
#
# File ~/clinic/climate-cabinet-tax-credit-map/env/lib/python3.8/site-packages/shapely/geometry/polygon.py:230, in Polygon.__new__(self, shell, holes)
#     228     return shell
#     229 else:
# --> 230     shell = LinearRing(shell)
#     232 if holes is not None:
#     233     if len(holes) == 0:
#     234         # shapely constructor cannot handle holes=[]
#
# File ~/clinic/climate-cabinet-tax-credit-map/env/lib/python3.8/site-packages/shapely/geometry/polygon.py:93, in LinearRing.__new__(self, coordinates)
#      90     else:
#      91         return [float(c) for c in o]
# ---> 93 coordinates = np.array([_coords(o) for o in coordinates])
#      94 if not np.issubdtype(coordinates.dtype, np.number):
#      95     # conversion of coords to 2D array failed, this might be due
#      96     # to inconsistent coordinate dimensionality
#      97     raise ValueError("Inconsistent coordinate dimensionality")
#
# File ~/clinic/climate-cabinet-tax-credit-map/env/lib/python3.8/site-packages/shapely/geometry/polygon.py:93, in <listcomp>(.0)
#      90     else:
#      91         return [float(c) for c in o]
# ---> 93 coordinates = np.array([_coords(o) for o in coordinates])
#      94 if not np.issubdtype(coordinates.dtype, np.number):
#      95     # conversion of coords to 2D array failed, this might be due
#      96     # to inconsistent coordinate dimensionality
#      97     raise ValueError("Inconsistent coordinate dimensionality")
#
# File ~/clinic/climate-cabinet-tax-credit-map/env/lib/python3.8/site-packages/shapely/geometry/polygon.py:88, in LinearRing.__new__.<locals>._coords(o)
#      87 def _coords(o):
# ---> 88     if isinstance(o, Point):
#      89         return o.coords[0]
#      90     else:
#
# KeyboardInterrupt:

# %%
import numpy as np
data = data.replace({np.nan: None})

# %%
def parse_tract(row):
    try:
        # Format tract id
        tract_id = row["GEOID10"]
        tract_num = tract_id[-6:-2].lstrip("0")
        block_grp = tract_id[-2:]
        fmd_tract = tract_num if block_grp == "00" else f"{tract_num}.{block_grp}"
        tract = f"CENSUS TRACT {fmd_tract}, "

        # Format county
        county = f"{row['CF'].upper()}, " if row["CF"] else ""

        # Format state
        state = f"{row['SF'].upper()}"

        # Compose name
        return f"{tract}{county}{state}"
    except Exception:
        print(row)
        raise

# %%
data["name"] = data.apply(parse_tract, axis=1)

# %%
gdf = gpd.read_file("../data/raw/usa.zip")
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 74134 entries, 0 to 74133
# Columns: 124 entries, GEOID10 to geometry
# dtypes: float64(50), geometry(1), int64(65), object(8)
# memory usage: 70.1+ MB

# %%
gdf.columns.tolist()
# Out:
# ['GEOID10',
#  'SF',
#  'CF',
#  'DF_PFS',
#  'AF_PFS',
#  'HDF_PFS',
#  'DSF_PFS',
#  'EBF_PFS',
#  'EALR_PFS',
#  'EBLR_PFS',
#  'EPLR_PFS',
#  'HBF_PFS',
#  'LLEF_PFS',
#  'LIF_PFS',
#  'LMI_PFS',
#  'PM25F_PFS',
#  'HSEF',
#  'P100_PFS',
#  'P200_I_PFS',
#  'AJDLI_ET',
#  'LPF_PFS',
#  'KP_PFS',
#  'NPL_PFS',
#  'RMP_PFS',
#  'TSDF_PFS',
#  'TPF',
#  'TF_PFS',
#  'UF_PFS',
#  'WF_PFS',
#  'UST_PFS',
#  'N_WTR',
#  'N_WKFC',
#  'N_CLT',
#  'N_ENY',
#  'N_TRN',
#  'N_HSG',
#  'N_PLN',
#  'N_HLTH',
#  'SN_C',
#  'SN_T',
#  'DLI',
#  'ALI',
#  'PLHSE',
#  'LMILHSE',
#  'ULHSE',
#  'EPL_ET',
#  'EAL_ET',
#  'EBL_ET',
#  'EB_ET',
#  'PM25_ET',
#  'DS_ET',
#  'TP_ET',
#  'LPP_ET',
#  'HRS_ET',
#  'KP_ET',
#  'HB_ET',
#  'RMP_ET',
#  'NPL_ET',
#  'TSDF_ET',
#  'WD_ET',
#  'UST_ET',
#  'DB_ET',
#  'A_ET',
#  'HD_ET',
#  'LLE_ET',
#  'UN_ET',
#  'LISO_ET',
#  'POV_ET',
#  'LMI_ET',
#  'IA_LMI_ET',
#  'IA_UN_ET',
#  'IA_POV_ET',
#  'TC',
#  'CC',
#  'IAULHSE',
#  'IAPLHSE',
#  'IALMILHSE',
#  'IALMIL_76',
#  'IAPLHS_77',
#  'IAULHS_78',
#  'LHE',
#  'IALHE',
#  'IAHSEF',
#  'N_CLT_EOMI',
#  'N_ENY_EOMI',
#  'N_TRN_EOMI',
#  'N_HSG_EOMI',
#  'N_PLN_EOMI',
#  'N_WTR_EOMI',
#  'N_HLTH_88',
#  'N_WKFC_89',
#  'FPL200S',
#  'N_WKFC_91',
#  'TD_ET',
#  'TD_PFS',
#  'FLD_PFS',
#  'WFR_PFS',
#  'FLD_ET',
#  'WFR_ET',
#  'ADJ_ET',
#  'IS_PFS',
#  'IS_ET',
#  'AML_ET',
#  'FUDS_RAW',
#  'FUDS_ET',
#  'IMP_FLG',
#  'DM_B',
#  'DM_AI',
#  'DM_A',
#  'DM_HI',
#  'DM_T',
#  'DM_W',
#  'DM_H',
#  'DM_O',
#  'AGE_10',
#  'AGE_MIDDLE',
#  'AGE_OLD',
#  'TA_COU_116',
#  'TA_COUNT_C',
#  'TA_PERC',
#  'TA_PERC_FE',
#  'UI_EXP',
#  'THRHLD',
#  'geometry']

# %%
gdf.head(2)
# Out:
#        GEOID10       SF                CF  DF_PFS  AF_PFS  HDF_PFS  DSF_PFS  \
# 0  01073001100  Alabama  Jefferson County    0.96    0.85     0.72     0.84
# 1  01073001400  Alabama  Jefferson County    0.98    0.83     0.92     0.93
#
#    EBF_PFS  EALR_PFS  EBLR_PFS  ...  AGE_10  AGE_MIDDLE  AGE_OLD  TA_COU_116  \
# 0     0.86      0.21      0.78  ...    0.13        0.66     0.20         NaN
# 1     0.97      0.08      0.91  ...    0.08        0.72     0.18         NaN
#
#    TA_COUNT_C  TA_PERC  TA_PERC_FE  UI_EXP  THRHLD  \
# 0         NaN      NaN         NaN  Nation      21
# 1         NaN      NaN         NaN  Nation      21
#
#                                             geometry
# 0  POLYGON ((-86.88244 33.55233, -86.88187 33.552...
# 1  POLYGON ((-86.84088 33.52759, -86.83782 33.528...
#
# [2 rows x 124 columns]

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.query("SN_C == 1")
# Out:
#            GEOID10              SF                CF  DF_PFS  AF_PFS  HDF_PFS  \
# 1      01073001400         Alabama  Jefferson County    0.98    0.83     0.92
# 2      01073002000         Alabama  Jefferson County    0.98    0.97     0.94
# 3      01073003802         Alabama  Jefferson County    0.95    0.91     0.62
# 4      01073004000         Alabama  Jefferson County    0.99    0.96     0.96
# 5      01073005101         Alabama  Jefferson County    0.99    0.99     0.98
# ...            ...             ...               ...     ...     ...      ...
# 74108  78010970800  Virgin Islands               NaN     NaN     NaN      NaN
# 74109  78010970900  Virgin Islands               NaN     NaN     NaN      NaN
# 74111  78010971100  Virgin Islands               NaN     NaN     NaN      NaN
# 74113  78010971300  Virgin Islands               NaN     NaN     NaN      NaN
# 74131  78030961200  Virgin Islands               NaN     NaN     NaN      NaN
#
#        DSF_PFS  EBF_PFS  EALR_PFS  EBLR_PFS  ...  AGE_10  AGE_MIDDLE  AGE_OLD  \
# 1         0.93     0.97      0.08      0.91  ...    0.08        0.72     0.18
# 2         0.76     0.93      0.08      0.64  ...    0.15        0.71     0.12
# 3         0.79     0.97      0.07      0.90  ...    0.14        0.72     0.13
# 4         0.86     0.98       NaN      0.95  ...    0.06        0.68     0.24
# 5         0.91     0.99       NaN      0.95  ...    0.30        0.62     0.07
# ...        ...      ...       ...       ...  ...     ...         ...      ...
# 74108      NaN      NaN       NaN       NaN  ...     NaN         NaN      NaN
# 74109      NaN      NaN       NaN       NaN  ...     NaN         NaN      NaN
# 74111      NaN      NaN       NaN       NaN  ...     NaN         NaN      NaN
# 74113      NaN      NaN       NaN       NaN  ...     NaN         NaN      NaN
# 74131      NaN      NaN       NaN       NaN  ...     NaN         NaN      NaN
#
#        TA_COU_116  TA_COUNT_C  TA_PERC  TA_PERC_FE        UI_EXP  THRHLD  \
# 1             NaN         NaN      NaN         NaN        Nation      21
# 2             NaN         NaN      NaN         NaN        Nation      21
# 3             NaN         NaN      NaN         NaN        Nation      21
# 4             NaN         NaN      NaN         NaN        Nation      21
# 5             NaN         NaN      NaN         NaN        Nation      21
# ...           ...         ...      ...         ...           ...     ...
# 74108         NaN         NaN      NaN         NaN  Island Areas       3
# 74109         NaN         NaN      NaN         NaN  Island Areas       3
# 74111         NaN         NaN      NaN         NaN  Island Areas       3
# 74113         NaN         NaN      NaN         NaN  Island Areas       3
# 74131         NaN         NaN      NaN         NaN  Island Areas       3
#
#                                                 geometry
# 1      POLYGON ((-86.84088 33.52759, -86.83782 33.528...
# 2      POLYGON ((-86.71390 33.53930, -86.71435 33.539...
# 3      POLYGON ((-86.90317 33.47177, -86.90284 33.472...
# 4      POLYGON ((-86.85463 33.48754, -86.85554 33.486...
# 5      POLYGON ((-86.83454 33.49894, -86.83439 33.499...
# ...                                                  ...
# 74108  POLYGON ((-64.77902 17.74375, -64.77886 17.743...
# 74109  POLYGON ((-64.82981 17.72959, -64.82980 17.729...
# 74111  POLYGON ((-64.86086 17.70709, -64.86077 17.706...
# 74113  POLYGON ((-64.84802 17.69677, -64.84837 17.696...
# 74131  POLYGON ((-64.92645 18.33021, -64.92883 18.328...
#
# [27248 rows x 124 columns]
