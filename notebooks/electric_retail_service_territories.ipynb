# %% [markdown]
# # Electric Retail Service Territories
#
# Exploratory data analysis for rural cooperatives and municipal utilities.

# %% [markdown]
# ### Summary
#
# The dataset has 2,949 records, 812 of which are rural cooperatives and 1,841 of which are municipal utilties. Relevant columns include the geometry, name (`NAME`), and state (`STATE`). The coordinate reference system is EPSG:4326.

# %% [markdown]
# ### Exploration

# %%
import geopandas as gpd
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# #### All Service Territories

# %%
gdf = gpd.read_file("../data/raw/bonus/retail/Electric_Retail_Service_Territories.zip")
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2949 entries, 0 to 2948
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    2949 non-null   int64
#  1   ID          2949 non-null   object
#  2   NAME        2949 non-null   object
#  3   ADDRESS     2949 non-null   object
#  4   CITY        2949 non-null   object
#  5   STATE       2949 non-null   object
#  6   ZIP         2949 non-null   object
#  7   TELEPHONE   2949 non-null   object
#  8   TYPE        2949 non-null   object
#  9   COUNTRY     2949 non-null   object
#  10  NAICS_CODE  2949 non-null   object
#  11  NAICS_DESC  2949 non-null   object
#  12  SOURCE      2949 non-null   object
#  13  SOURCEDATE  2949 non-null   object
#  14  VAL_METHOD  2949 non-null   object
#  15  VAL_DATE    2949 non-null   object
#  16  WEBSITE     2949 non-null   object
#  17  REGULATED   2949 non-null   object
#  18  CNTRL_AREA  2949 non-null   object
#  19  PLAN_AREA   2949 non-null   object
#  20  HOLDING_CO  2949 non-null   object
#  21  SUMMR_PEAK  2949 non-null   float64
#  22  WINTR_PEAK  2949 non-null   float64
#  23  SUMMER_CAP  2949 non-null   float64
#  24  WINTER_CAP  2949 non-null   float64
#  25  NET_GEN     2949 non-null   int64
#  26  PURCHASED   2949 non-null   int64
#  27  NET_EX      2949 non-null   int64
#  28  RETAIL_MWH  2949 non-null   int64
#  29  WSALE_MWH   2949 non-null   int64
#  30  TOTAL_MWH   2949 non-null   int64
#  31  TRANS_MWH   2949 non-null   int64
#  32  CUSTOMERS   2949 non-null   int64
#  33  YEAR        2949 non-null   object
#  34  Shape__Are  2949 non-null   float64
#  35  Shape__Len  2949 non-null   float64
#  36  geometry    2949 non-null   geometry
# dtypes: float64(6), geometry(1), int64(9), object(21)
# memory usage: 852.6+ KB

# %%
gdf.columns
# Out:
# Index(['OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'TELEPHONE', 'TYPE', 'COUNTRY', 'NAICS_CODE', 'NAICS_DESC', 'SOURCE',
#        'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'REGULATED',
#        'CNTRL_AREA', 'PLAN_AREA', 'HOLDING_CO', 'SUMMR_PEAK', 'WINTR_PEAK',
#        'SUMMER_CAP', 'WINTER_CAP', 'NET_GEN', 'PURCHASED', 'NET_EX',
#        'RETAIL_MWH', 'WSALE_MWH', 'TOTAL_MWH', 'TRANS_MWH', 'CUSTOMERS',
#        'YEAR', 'Shape__Are', 'Shape__Len', 'geometry'],
#       dtype='object')

# %%
gdf.head(2)
# Out:
#    OBJECTID     ID                    NAME           ADDRESS           CITY  \
# 0         1   1000  CITY OF AUGUSTA - (AR)     NOT AVAILABLE  NOT AVAILABLE
# 1         2  10000            EVERGY METRO  1200 MAIN STREET    KANSAS CITY
#
#   STATE            ZIP      TELEPHONE            TYPE COUNTRY NAICS_CODE  \
# 0    AR  NOT AVAILABLE  NOT AVAILABLE       MUNICIPAL     USA       2211
# 1    KS          64105  NOT AVAILABLE  INVESTOR OWNED     USA       2211
#
#                                           NAICS_DESC  \
# 0  ELECTRIC POWER GENERATION, TRANSMISSION AND DI...
# 1  ELECTRIC POWER GENERATION, TRANSMISSION AND DI...
#
#                                               SOURCE  SOURCEDATE VAL_METHOD  \
# 0       EIA 861, TIGER/Line Shapefiles - U.S. Census  2021-10-06      OTHER
# 1  https://www.kcpl.com/-/media/indexedmedia/abou...  2021-10-06      OTHER
#
#      VAL_DATE                  WEBSITE      REGULATED  \
# 0  2018-10-12            NOT AVAILABLE  NOT AVAILABLE
# 1  2021-04-30  https://www.evergy.com/  NOT AVAILABLE
#
#                                           CNTRL_AREA      PLAN_AREA  \
# 0  MIDCONTINENT INDEPENDENT TRANSMISSION SYSTEM O...  NOT AVAILABLE
# 1                               SOUTHWEST POWER POOL  NOT AVAILABLE
#
#                      HOLDING_CO  SUMMR_PEAK  WINTR_PEAK  SUMMER_CAP  \
# 0        CITY OF AUGUSTA - (AR)   -999999.0   -999999.0   -999999.0
# 1  KANSAS CITY POWER & LIGHT CO      3200.0      2484.0      4877.8
#
#    WINTER_CAP   NET_GEN  PURCHASED  NET_EX  RETAIL_MWH  WSALE_MWH  TOTAL_MWH  \
# 0   -999999.0     12823    -999999 -999999     -999999    -999999    -999999
# 1   -999999.0  14911882    5624474       0    14223892    5957441   20536356
#
#    TRANS_MWH  CUSTOMERS  YEAR  Shape__Are  Shape__Len  \
# 0    -999999        916  2020    0.152271    2.625553
# 1          0     562180  2020    0.525845   10.131485
#
#                                             geometry
# 0  POLYGON ((-91.34713 35.43899, -91.34711 35.439...
# 1  MULTIPOLYGON (((-94.66607 38.27027, -94.66941 ...

# %%
gdf["STATE"].sort_values().unique()
# Out:
# array(['AB', 'AK', 'AL', 'AR', 'AS', 'AZ', 'BC', 'CA', 'CO', 'CT', 'DC',
#        'DE', 'FL', 'GA', 'GU', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY',
#        'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MP', 'MS', 'MT', 'NC',
#        'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA',
#        'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VI', 'VT', 'WA',
#        'WI', 'WV', 'WY'], dtype=object)

# %% [markdown]
# NOTE: The dataset contains utilities that are located outside the United States:
#
# - AB - Canada
# - AS - American Samoa
# - BC - Canada
# - DC - District of Columbia
# - GU - Guam
# - MP - Northern Mariana Islands
# - PR - Puerto Rico
# - VI - Virgin Islands

# %%
gdf["TYPE"].sort_values().unique().tolist()
# Out:
# ['COMMUNITY CHOICE AGGREGATOR',
#  'COOPERATIVE',
#  'FEDERAL',
#  'INVESTOR OWNED',
#  'MUNICIPAL',
#  'MUNICIPAL MKTG AUTHORITY',
#  'NOT AVAILABLE',
#  'POLITICAL SUBDIVISION',
#  'STATE',
#  'WHOLESALE POWER MARKETER']

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### Municipalities

# %%
municipal_types = ['MUNICIPAL', 'MUNICIPAL MKTG AUTHORITY']
municipalities = gdf.query("TYPE in @municipal_types")
municipalities.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1841 entries, 0 to 2948
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    1841 non-null   int64
#  1   ID          1841 non-null   object
#  2   NAME        1841 non-null   object
#  3   ADDRESS     1841 non-null   object
#  4   CITY        1841 non-null   object
#  5   STATE       1841 non-null   object
#  6   ZIP         1841 non-null   object
#  7   TELEPHONE   1841 non-null   object
#  8   TYPE        1841 non-null   object
#  9   COUNTRY     1841 non-null   object
#  10  NAICS_CODE  1841 non-null   object
#  11  NAICS_DESC  1841 non-null   object
#  12  SOURCE      1841 non-null   object
#  13  SOURCEDATE  1841 non-null   object
#  14  VAL_METHOD  1841 non-null   object
#  15  VAL_DATE    1841 non-null   object
#  16  WEBSITE     1841 non-null   object
#  17  REGULATED   1841 non-null   object
#  18  CNTRL_AREA  1841 non-null   object
#  19  PLAN_AREA   1841 non-null   object
#  20  HOLDING_CO  1841 non-null   object
#  21  SUMMR_PEAK  1841 non-null   float64
#  22  WINTR_PEAK  1841 non-null   float64
#  23  SUMMER_CAP  1841 non-null   float64
#  24  WINTER_CAP  1841 non-null   float64
#  25  NET_GEN     1841 non-null   int64
#  26  PURCHASED   1841 non-null   int64
#  27  NET_EX      1841 non-null   int64
#  28  RETAIL_MWH  1841 non-null   int64
#  29  WSALE_MWH   1841 non-null   int64
#  30  TOTAL_MWH   1841 non-null   int64
#  31  TRANS_MWH   1841 non-null   int64
#  32  CUSTOMERS   1841 non-null   int64
#  33  YEAR        1841 non-null   object
#  34  Shape__Are  1841 non-null   float64
#  35  Shape__Len  1841 non-null   float64
#  36  geometry    1841 non-null   geometry
# dtypes: float64(6), geometry(1), int64(9), object(21)
# memory usage: 546.5+ KB

# %%
municipalities.head(2)
# Out:
#    OBJECTID    ID                    NAME        ADDRESS           CITY STATE  \
# 0         1  1000  CITY OF AUGUSTA - (AR)  NOT AVAILABLE  NOT AVAILABLE    AR
# 6         7  1002  CITY OF AURELIA - (IA)  NOT AVAILABLE  NOT AVAILABLE    IA
#
#              ZIP      TELEPHONE       TYPE COUNTRY NAICS_CODE  \
# 0  NOT AVAILABLE  NOT AVAILABLE  MUNICIPAL     USA       2211
# 6  NOT AVAILABLE  NOT AVAILABLE  MUNICIPAL     USA       2211
#
#                                           NAICS_DESC  \
# 0  ELECTRIC POWER GENERATION, TRANSMISSION AND DI...
# 6  ELECTRIC POWER GENERATION, TRANSMISSION AND DI...
#
#                                          SOURCE  SOURCEDATE VAL_METHOD  \
# 0  EIA 861, TIGER/Line Shapefiles - U.S. Census  2021-10-06      OTHER
# 6  EIA 861, TIGER/Line Shapefiles - U.S. Census  2021-10-06      OTHER
#
#      VAL_DATE        WEBSITE      REGULATED  \
# 0  2018-10-12  NOT AVAILABLE  NOT AVAILABLE
# 6  2018-10-12  NOT AVAILABLE  NOT AVAILABLE
#
#                                           CNTRL_AREA      PLAN_AREA  \
# 0  MIDCONTINENT INDEPENDENT TRANSMISSION SYSTEM O...  NOT AVAILABLE
# 6  MIDCONTINENT INDEPENDENT TRANSMISSION SYSTEM O...  NOT AVAILABLE
#
#                HOLDING_CO  SUMMR_PEAK  WINTR_PEAK  SUMMER_CAP  WINTER_CAP  \
# 0  CITY OF AUGUSTA - (AR)   -999999.0   -999999.0   -999999.0   -999999.0
# 6  CITY OF AURELIA - (IA)   -999999.0   -999999.0   -999999.0   -999999.0
#
#    NET_GEN  PURCHASED  NET_EX  RETAIL_MWH  WSALE_MWH  TOTAL_MWH  TRANS_MWH  \
# 0    12823    -999999 -999999     -999999    -999999    -999999    -999999
# 6     7441    -999999 -999999     -999999    -999999    -999999    -999999
#
#    CUSTOMERS  YEAR  Shape__Are  Shape__Len  \
# 0        916  2020    0.152271    2.625553
# 6        518  2020    0.164284    1.639697
#
#                                             geometry
# 0  POLYGON ((-91.34713 35.43899, -91.34711 35.439...
# 6  POLYGON ((-95.85936 42.90908, -95.85125 42.909...

# %% [markdown]
# #### Rural Cooperatives

# %%
coops_types = ['COOPERATIVE']
coops = gdf.query("TYPE in @coops_types")
coops.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 812 entries, 3 to 2792
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    812 non-null    int64
#  1   ID          812 non-null    object
#  2   NAME        812 non-null    object
#  3   ADDRESS     812 non-null    object
#  4   CITY        812 non-null    object
#  5   STATE       812 non-null    object
#  6   ZIP         812 non-null    object
#  7   TELEPHONE   812 non-null    object
#  8   TYPE        812 non-null    object
#  9   COUNTRY     812 non-null    object
#  10  NAICS_CODE  812 non-null    object
#  11  NAICS_DESC  812 non-null    object
#  12  SOURCE      812 non-null    object
#  13  SOURCEDATE  812 non-null    object
#  14  VAL_METHOD  812 non-null    object
#  15  VAL_DATE    812 non-null    object
#  16  WEBSITE     812 non-null    object
#  17  REGULATED   812 non-null    object
#  18  CNTRL_AREA  812 non-null    object
#  19  PLAN_AREA   812 non-null    object
#  20  HOLDING_CO  812 non-null    object
#  21  SUMMR_PEAK  812 non-null    float64
#  22  WINTR_PEAK  812 non-null    float64
#  23  SUMMER_CAP  812 non-null    float64
#  24  WINTER_CAP  812 non-null    float64
#  25  NET_GEN     812 non-null    int64
#  26  PURCHASED   812 non-null    int64
#  27  NET_EX      812 non-null    int64
#  28  RETAIL_MWH  812 non-null    int64
#  29  WSALE_MWH   812 non-null    int64
#  30  TOTAL_MWH   812 non-null    int64
#  31  TRANS_MWH   812 non-null    int64
#  32  CUSTOMERS   812 non-null    int64
#  33  YEAR        812 non-null    object
#  34  Shape__Are  812 non-null    float64
#  35  Shape__Len  812 non-null    float64
#  36  geometry    812 non-null    geometry
# dtypes: float64(6), geometry(1), int64(9), object(21)
# memory usage: 241.1+ KB

# %%
coops.head(2)
# Out:
#    OBJECTID     ID                      NAME           ADDRESS         CITY  \
# 3         4  10009  KARNES ELECTRIC COOP INC  1007 N. HWY. 123  KARNES CITY
# 4         5  10012         KAY ELECTRIC COOP     300 W. DOOLIN    BLACKWELL
#
#   STATE    ZIP       TELEPHONE         TYPE COUNTRY NAICS_CODE  \
# 3    TX  78118  (830) 780-3952  COOPERATIVE     USA       2211
# 4    OK  74631  (580) 363-1260  COOPERATIVE     USA       2211
#
#                                           NAICS_DESC  \
# 3  ELECTRIC POWER GENERATION, TRANSMISSION AND DI...
# 4  ELECTRIC POWER GENERATION, TRANSMISSION AND DI...
#
#                                               SOURCE  SOURCEDATE VAL_METHOD  \
# 3       EIA 861, TIGER/Line Shapefiles - U.S. Census  2021-10-06      OTHER
# 4  EIA 861, TIGER/Line Shapefiles - U.S. Census, ...  2021-10-06      OTHER
#
#      VAL_DATE                   WEBSITE      REGULATED  \
# 3  2018-10-12  http://www.karnesec.org/  NOT AVAILABLE
# 4  2019-05-01      www.kayelectric.coop  NOT AVAILABLE
#
#                                     CNTRL_AREA  \
# 3  ELECTRIC RELIABILITY COUNCIL OF TEXAS, INC.
# 4                         SOUTHWEST POWER POOL
#
#                               PLAN_AREA                HOLDING_CO  SUMMR_PEAK  \
# 3                                 ERCOT  KARNES ELECTRIC COOP INC       207.0
# 4  WESTERN FARMERS ELECTRIC COOPERATIVE         KAY ELECTRIC COOP        71.0
#
#    WINTR_PEAK  SUMMER_CAP  WINTER_CAP  NET_GEN  PURCHASED  NET_EX  RETAIL_MWH  \
# 3       208.0   -999999.0   -999999.0  -999999    1170464       0     1129899
# 4        71.0   -999999.0   -999999.0        0     378230       0      371371
#
#    WSALE_MWH  TOTAL_MWH  TRANS_MWH  CUSTOMERS  YEAR  Shape__Are  Shape__Len  \
# 3    -999999    1170464          0      21327  2020    3.085930    8.976781
# 4          0     378230          0       5785  2020    0.599957    3.978050
#
#                                             geometry
# 3  POLYGON ((-98.54256 29.75188, -98.54102 29.751...
# 4  POLYGON ((-97.74419 36.93999, -97.74638 36.977...
